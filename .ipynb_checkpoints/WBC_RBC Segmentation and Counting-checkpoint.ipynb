# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img=plt.imread("blood.jpeg")
r,g,b=cv2.split(img)
min=g.min()
max=g.max()
mod=cv2.normalize(g, g, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)
#mod=[ for i in g

counter=0
for i in g:
    mod[counter]=((i-min)/max-min)*255
    counter=counter+1

#blur = cv2.GaussianBlur(mod,(5,5),0)
ret,th1 =cv2.threshold(mod,90,255,cv2.THRESH_BINARY)
comple=cv2.bitwise_not(th1)


kernel = np.ones((3,3), np.uint8)

kernel1 = np.ones((5,5), np.uint8)

img_erosion = cv2.erode(comple, kernel, iterations=1)

edge=cv2.Canny(img_erosion,10,200)

img_dilation = cv2.dilate(edge, kernel1, iterations=1)


# hist = cv2.calcHist([mod], [0], None, [256], [0, 256])
# plt.figure()
# plt.title(" Histogram MOD")
# plt.xlabel("Bins")
# plt.ylabel("# of Pixels")
# plt.plot(hist)
# plt.xlim([0, 256])
# plt.show()

# %%
res=np.hstack([mod,th1,comple])
res1=np.hstack([img_erosion,edge,img_dilation])
final=np.hstack([res,res1])
plt.imshow(res)
plt.show()
plt.imshow(res1)
plt.show()

cv2.imwrite('wbc.png',final)
# Out:
# True

# %%
import cv2
import numpy as np

im2,contours,hierarchy = cv2.findContours(comple, 1, 2)
#cnt = contours[0]
for cnt in contours:
    M = cv2.moments(cnt)
    area = cv2.contourArea(cnt)
# print (M)
# print (area)
    x,y,w,h = cv2.boundingRect(cnt)
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    
plt.imshow(img)
plt.show()
avg_area=area/(len(contours))
len(contours)
# Out:
# 31

# %%
img=plt.imread("blood.jpeg")
r,g,b=cv2.split(img)
min=g.min()
max=g.max()
mod=cv2.normalize(g, g, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)
#mod=[ for i in g]
counter=0
for i in g:
    mod[counter]=((i-min)/max-min)*255
    counter=counter+1

blur = cv2.GaussianBlur(mod,(15,15),0)
ret,th2 =cv2.threshold(blur,140,255,cv2.THRESH_BINARY)
comple1=cv2.bitwise_not(th2)

sub=cv2.subtract(comple1,comple)
#sub=cv2.subtract(sub,img_dilation)

kernel11 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(6,6))
sub = cv2.morphologyEx(sub,cv2.MORPH_OPEN,kernel11)


kernel = np.ones((3,3), np.uint8)

# img_erosion = cv2.erode(comple, kernel, iterations=1)

edge1=cv2.Canny(sub,10,20)

img_dilation1 = cv2.dilate(edge1, kernel, iterations=1)

# %%
res=np.hstack([mod,th2,comple1])
res1=np.hstack([sub,edge1,img_dilation1])
final=np.hstack([res,res1])
plt.imshow(res)
plt.show()
plt.imshow(res1)
plt.show()
plt.imshow(edge1)
plt.show()
cv2.imwrite('rbc.png',final)
# Out:
# True

# %%
#p=cv2.imread('blood.jpeg',0)
#greys = cv2.cvtColor(p,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(sub,cv2.HOUGH_GRADIENT,11,10,param1=50,param2=55,minRadius=6,maxRadius=21)
# ensure at least some circles were found
if circles is not None:
    circles = np.round(circles[0, :]).astype("int")
 
# loop over the (x, y) coordinates and radius of the circles
for (x, y, r) in circles:
    cv2.circle(g, (x, y), r, (55, 255, 10), 1)
    #cv2.rectangle(img, (x - 5, y - 5), (x + 5, y + 5), (0, 128, 255), -1)

plt.imshow(g)
plt.show()
res=np.hstack([g,sub])
cv2.imwrite("rbc_de.png",res)
# Out:
# True

# %%
# find contours in the thresholded image
cnts = cv2.findContours(sub.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)[-2]
print("[INFO] {} unique contours found".format(len(cnts)))
 
# loop over the contours
for (i, c) in enumerate(cnts):
# draw the contour
    ((x, y), _) = cv2.minEnclosingCircle(c)
    #cv2.putText(g, "#{}".format(i + 1), (int(x) - 10, int(y)),cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)
    cv2.drawContours(g, [c], -1, (0, 255, 0), 2)
 
# show the output image
plt.imshow(g)
plt.show()
res=np.hstack([g,sub])
cv2.imwrite("rbc_ws.png",res)
# Out:
# [INFO] 142 unique contours found
# True

# %%
from scipy import ndimage
from skimage.feature import peak_local_max
from skimage.morphology import watershed

D = ndimage.distance_transform_edt(th2)
localMax = peak_local_max(D, indices=False, min_distance=20,labels=th2)
 
plt.imshow(D)
plt.show()
    
# perform a connected component analysis on the local peaks,
# using 8-connectivity, then appy the Watershed algorithm
markers = ndimage.label(localMax, structure=np.ones((3, 3)))[0]
labels = watershed(-D, markers, mask=th2)
print("[INFO] {} unique segments found".format(len(np.unique(labels)) - 1))


for label in np.unique(labels):
# if the label is zero, we are examining the 'background'
# so simply ignore it
    if label == 0:
        continue
 
# otherwise, allocate memory for the label region and draw
# it on the mask
    mask = np.zeros(g.shape, dtype="uint8")
    mask[labels == label] = 255
    
 
# # detect contours in the mask and grab the largest one
    cnts = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)[-2]
    c = max(cnts, key=cv2.contourArea)
#     #print (c)
 
# draw a circle enclosing the object
    #for (i, c) in enumerate(cnts):
# draw the contour
    
    ((x, y), r) = cv2.minEnclosingCircle(c)
    cv2.circle(g, (int(x), int(y)), int(r), (0, 255, 0), 2)

plt.imshow(g)
plt.show()
res=np.hstack([g,sub])
cv2.imwrite("rbc_ws1.png",res)
# Out:
# [INFO] 67 unique segments found
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-246-a7eb1e6a9d2e> in <module>()
#      30 # # detect contours in the mask and grab the largest one
#      31     cnts = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)[-2]
# ---> 32     c = max(cnts, key=cv2.contourArea)
#      33 #     #print (c)
#      34
#
# TypeError: 'numpy.uint8' object is not callable

# %%
from skimage import morphology
import cv2
import numpy as np
import sys


def get_image():
    size = (w, h) = (100, 100)
    img = mod
    return img


def show_image(img):
    plt.imshow(img)
    plt.show()


if __name__ == '__main__':
    img = get_image()
    show_image(img)

    labels = morphology.label(img, background=0)
    label_number = 0
    while True:
        temp = np.uint8(labels==label_number) * 255
        if not cv2.countNonZero(temp):
            break
        #show_image(temp)
        label_number += 1

   # cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-27e1fe7643f8> in <module>()
#      23     label_number = 0
#      24     while True:
# ---> 25         temp = np.uint8(labels==label_number) * 255
#      26         if not cv2.countNonZero(temp):
#      27             break
#
# KeyboardInterrupt:

# %%
labels.shape

# %%
plt.imshow()
plt.show()
plt.imshow(img)
plt.show()
